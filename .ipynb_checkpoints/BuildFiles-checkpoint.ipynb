# %%
import os

# %%
# Load .md file

with open('PlanetStories.md', encoding="utf8") as f:
    lines = f.read().splitlines()

# parse it

articles = []
magazine = {}
block = { 'stories': [] }
story = {}

# print(lines[0:20])

for line in lines:
    raw_line = line.replace('\n', '')
        
    if len(line) == 0:
        continue
    
    if line.startswith("# "):
        if 'title' in story:
            block['stories'].append(story)

        if len(block['stories']) > 0:
            magazine['blocks'].append(block)
        
        if len(magazine) > 0:
            articles.append(magazine)

        magazine = { 'folder': line[2:], 'blocks': [] }
        block = { 'stories': [] }
        story = {}
        continue
        
    if line.startswith("## "):
        if 'title' in story:
            block['stories'].append(story)
        
        if len(block['stories']) > 0:
            magazine['blocks'].append(block)
        
        block = { 'title': line[3:], 'stories': [] }
        story = {}
        continue

    if line.startswith("### "):
        if 'title' in story:
            block['stories'].append(story)
        
        story = { 'title': line[4:]}
        continue
        
    if line.startswith("#### "):
        story['author'] = line[5:]
        continue
        
    story['intro'] = line    
                 
if 'title' in story:
    block['stories'].append(story)

if len(block['stories']) > 0:
    magazine['blocks'].append(block)
    
if len(magazine) > 0:
    articles.append(magazine)

# %%
articles[:11]
# Out:
# [{'folder': 'v01n02',
#   'blocks': [{'title': 'TWO GREAT NOVELS OF ADVENTURE IN SPACE AND TIME',
#     'stories': [{'title': 'GODDESS OF THE MOON',
#       'author': 'John Murray Reynolds',
#       'intro': 'Death hid behind a smile in the white-and-gold lunar city of Gral-Thala. But Gibson, adventurer in space, knew that if he died the Good Green planet perished with him.'},
#      {'title': 'DICTATOR OF TIME',
#       'author': 'Nelson S. Bond',
#       'intro': 'Twentieth-century Larry Wilson and Sandra Day lead the Armageddon of the Ages against Harg, crafty, vain monster-intellect, bent on warping Man to his Inhuman Will!'}]},
#    {'title': 'THREE EXCITING NOVELETS OF THE LOST WORLDS',
#     'stories': [{'title': 'THE GIRL FROM INFINITE SMALLNESS',
#       'author': 'Ray Cummings',
#       'intro': 'The terrified Princess of Heanas burst into a different space-sphere to find an earthling champion. For the vicious Tarch had thieved the formula of transcendent growth.'},
#      {'title': 'MARTIAN TERROR',
#       'author': 'Ed Earl Repp',
#       'intro': 'Lolan loved the Princess Mora, but when her desperate Venusians raised their empty fists, duty commanded the soldier to blast them to eternity with his force-bolts!'},
#      {'title': 'REVOLT ON THE EARTH-STAR',
#       'author': 'Carl Selwyn',
#       'intro': 'Lonely derelict from a happier earth-age, Carver raises the revolt-cry: “Down with the Capeks!” And the luxurious, human stockyards discharge their men-of-no-hope.'}]},
#    {'title': 'THREE SMASHING SHORT STORIES',
#     'stories': [{'title': 'THE TANTALUS DEATH',
#       'author': 'Ross Rocklynne',
#       'intro': "Earth denied the Red Planet's frantic H2O-plea. So began the Reign of Terror."},
#      {'title': 'THE SPACE FLAME',
#       'author': 'Alexander M. Phillips',
#       'intro': 'On that derelict space-ship, Death hissed and coiled and struck with tongues of flame!'},
#      {'title': 'THE MAN WHO KILLED THE EARTH',
#       'author': 'Ray King',
#       'intro': "One day Groff's brain would crack—and the World would dissolve into chaos."}]},
#    {'title': 'PS’s DEPARTMENTS',
#     'stories': [{'title': 'THE FEATURE FLASH',
#       'intro': 'The story of men’s lives is the tale of their writings. Brief flashes....'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Kicks, kudos, bombs and bouquets—helpful and interesting letters welcome.'}]}]},
#  {'folder': 'v01n03',
#   'blocks': [{'title': 'A SMASHING NOVEL OF SPACE MUTINY',
#     'stories': [{'title': 'SPACE-LINER X-87',
#       'author': 'Ray Cummings',
#       'intro': 'The X-87 was a red shambles... a horror-ship roaring the far-flung star-ways.'}]},
#    {'title': 'FOUR NOVELETS OF LOST WORLDS',
#     'stories': [{'title': 'THE FORBIDDEN DREAM',
#       'author': 'Ross Rocklynne',
#       'intro': 'Deep in the brain of fallen Ganymede was a dream of universal cataclysm.'},
#      {'title': 'EXILES OF THE THREE RED MOONS',
#       'author': 'Carl Selwyn',
#       'intro': 'Already Carter could feel the slow Emerald Death of that devil’s planet.'},
#      {'title': 'THE COSMIC JUGGERNAUT',
#       'author': 'John Russell Fearn',
#       'intro': 'Valno tampered with Creation’s law to avoid the chaos of a world gone wild.'},
#      {'title': 'THE DARK SWORDSMEN OF SATURN',
#       'author': 'Neil R. Jones',
#       'intro': 'It was revenge that lured Lindquist to the stronghold of Saturn’s dark swordsmen.'}]},
#    {'title': 'THREE PLANET SHORT STORIES',
#     'stories': [{'title': 'SPHERE OF THE NEVER-DEAD',
#       'author': 'Sam Carson',
#       'intro': 'Kenley was slated for the Death-in-Life. Only a cosmic revolt could save him.'},
#      {'title': 'STAR PIRATE',
#       'author': 'Frederick A. Rummer, Jr.',
#       'intro': 'A cool million in Cerean palladium was tempting bait to that exiled star-pirate.'},
#      {'title': 'ASTEROID H277—PLUS',
#       'author': 'Harry Walton',
#       'intro': 'Mutiny and murder was the web that Akars spun aboard the doomed Sun-freighter.'}]},
#    {'title': 'PS’s DEPARTMENTS',
#     'stories': [{'title': 'LIFE ON OTHER PLANETS?',
#       'author': 'Edward Podolsky',
#       'intro': 'A stimulating article dealing with the possibility of life on other worlds.'},
#      {'title': 'THE FEATURE FLASH',
#       'intro': 'A glimpse behind the scenes at the authors and artists who set the Planet stage.'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Come one, come all to PS’s forum.... The admission price is only a letter.'}]}]},
#  {'folder': 'v01n04',
#   'blocks': [{'title': 'TWO UNUSUAL PLANET NOVELS',
#     'stories': [{'title': 'THE ULTIMATE SALIENT',
#       'author': 'Nelson S. Bond',
#       'intro': 'Brian O’Shea... man of the future, soldier yet unborn... here is your story!'},
#      {'title': 'REVOLT IN THE ICE KINGDOM',
#       'author': 'Ray Cummings',
#       'intro': 'Zura was a stellar Utopia, until Earthmen sowed their evil seeds of greed and revolt.'}]},
#    {'title': 'TWO NOVELETS OF LOST WORLDS',
#     'stories': [{'title': 'BUCCANEER OF THE STAR SEAS',
#       'author': 'Ed Earl Repp',
#       'intro': 'Immortal... yet Carlyle sought death in the sargasso of missing space-galleons.'},
#      {'title': 'DOMAIN OF ZERO',
#       'author': 'Thornton Ayre',
#       'intro': 'Spacemen avoided Callisto, domain of the warped brain who called himself “Zero.”'}]},
#    {'title': 'FOUR PLANET SHORT STORIES',
#     'stories': [{'title': 'QUEST ON IO',
#       'author': 'Robert Moore Williams',
#       'intro': 'Io, peril-starred satellite of Jupiter, was dangerous ground for the Earth-kind.'},
#      {'title': 'THE PLANET THAT TIME FORGOT',
#       'author': 'Donald A. Wollheim',
#       'intro': 'Ever-brighter loomed the monstrous new planet—the Colossus that Time forgot.'},
#      {'title': 'HERMIT OF SATURN’S RING',
#       'author': 'Neil R. Jones',
#       'intro': 'Alone aboard a coffin-ship, old Jasper waited the return of the White Death.'},
#      {'title': 'VENUS HAS GREEN EYES',
#       'author': 'Carl Selwyn',
#       'intro': 'The hard-cased space-explorer was no match for the stormy green-eyed queen.'}]},
#    {'title': 'PS’s DEPARTMENTS',
#     'stories': [{'title': 'THE FEATURE FLASH',
#       'intro': 'A glimpse behind the scenes at the authors and artists who set the Planet stage.'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Read the list of prize letters along with the winners’ choices of illustrations.'}]}]},
#  {'folder': 'v01n05',
#   'blocks': [{'title': 'A THRILLING PLANET NOVEL',
#     'stories': [{'title': 'ONE THOUSAND MILES BELOW',
#       'author': 'Eando Binder',
#       'intro': 'Up from Earth’s depth, came a strange, pale army to battle the Martian Ray Armada.'}]},
#    {'title': 'TWO NOVELETS OF LOST WORLDS',
#     'stories': [{'title': 'PHANTOM OF THE SEVEN STARS',
#       'author': 'Ray Cummings',
#       'intro': 'A phantom pirate had marked the life-precious cargo of the *Seven Stars* for plunder.'},
#      {'title': 'TWILIGHT OF THE TENTH WORLD',
#       'author': 'Thornton Ayre ',
#       'intro': '“We, your masters, have failed!” The message panicked the doomed World.'}]},
#    {'title': 'FIVE PLANET SHORT STORIES',
#     'stories': [{'title': 'THE CASTAWAY',
#       'author': 'George Danzell',
#       'intro': 'Brait knew the space wanderer by a name that was old when the world was young.'},
#      {'title': 'ATOM OF DEATH',
#       'author': 'Ross Rocklynne',
#       'intro': 'An atom was to have been the killer’s alibi—but instead it was judge and executioner.'},
#      {'title': 'BEYOND LIGHT',
#       'author': 'Nelson S. Bond',
#       'intro': 'Deep in Venus’ caverns... beyond light... beyond imagination, dwelt Horror.'},
#      {'title': 'EXIT FROM ASTEROID 60',
#       'author': 'D. L. James',
#       'intro': 'Strange things were happening in the deep core of Echo, weird Martian satellite.'},
#      {'title': 'THE STELLAR LEGION',
#       'author': 'Leigh Brackett',
#       'intro': 'Thekla, the low-Martian, learned no one betrayed the Steller Legion—and lived.'},
#      {'title': 'THE FEATURE FLASH',
#       'intro': 'A glimpse behind the scenes at the authors and artists who set the Planet stage.'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Read the list of prize letters along with the winners’ choices of illustrations.'}]}]},
#  {'folder': 'v01n06',
#   'blocks': [{'title': 'A STIRRING PLANET NOVEL',
#     'stories': [{'title': 'THE WAR-NYMPHS OF VENUS',
#       'author': 'Ray Cummings',
#       'intro': 'The voluptuous, golden civilization of Arron was doomed. Licentious laughter echoed through the water-kingdom, unmindful of the clanking, relentless invasion of the Gorts. What fools, this handful of warrior-maidens, to pit their thin strength against Tollgamo’s iron legions.'}]},
#    {'title': 'THREE NOVELETS OF OTHER WORLDS',
#     'stories': [{'title': 'VAMPIRE OF THE VOID',
#       'author': 'Neil R. Jones',
#       'intro': 'Aonis was the loveliest creature in four worlds—and the most deadly.'},
#      {'title': 'EXILES OF THE DESERT STAR',
#       'author': 'Ross Rocklynne',
#       'intro': 'The rebel Kreuther had woven a pretty murder web about the Io-plunging *Libra*.'}]},
#    {'title': 'FIVE PLANET SHORT STORIES',
#     'stories': [{'title': 'THE MONSTER THAT THREATENED THE UNIVERSE',
#       'author': 'R. R. Winterbotham',
#       'intro': 'Effete Earth was helpless to battle the destroying monster of Chaos.'},
#      {'title': 'TREASURE OF TRITON',
#       'author': 'Charles A. Baker',
#       'intro': 'Men sold their sonls to possess the Eye of Triton, creation’s richest prize.'},
#      {'title': 'THE COSMIC DERELICT',
#       'author': 'John Russell Fearn',
#       'intro': 'The *Voitrix* was doomed... a helpless derelict flashing to cosmic annihilation.'},
#      {'title': '4½ B, EROS',
#       'author': 'Malcolm Jameson',
#       'intro': 'Strange things happened to ships and cargoes on the hoodooed Mercury-Venus run.'},
#      {'title': 'SATELLITE OF FEAR',
#       'author': 'Frederick Arnold Kummer, Jr.',
#       'intro': 'Death in spectral form stalked the frozen surface of Ceres’ fabled Darkside.'},
#      {'title': 'THE VIZIGRAPH'}]}]},
#  {'folder': 'v01n07',
#   'blocks': [{'title': 'FOUR BIG PLANET NOVELETS',
#     'stories': [{'title': 'INVADERS OF THE FORBIDDEN MOON',
#       'author': 'Raymond Z. Gallun',
#       'intro': 'Harwich blasted from Jupiter to solve the riddle of a cosmic death-trap.'},
#      {'title': 'SARGASSO OF THE STARS',
#       'author': 'Frederick A. Kummer, Jr.',
#       'intro': 'The “Spot” was the curse of the Universe; a drifting Sargasso of lost space-ships.'},
#      {'title': 'MUTINY ABOARD THE “TERRA”',
#       'author': 'Ross Roeklynne',
#       'intro': 'A lovely stowaway sparked the mutiny-threatened “Terra” into a hell-ship.'},
#      {'title': 'PROKTOLS OF NEPTUNE',
#       'author': 'Henry Hasse',
#       'intro': 'Space-rumor spun horror-tales about Neptune’s almost-legendary race of Proktols.'}]},
#    {'title': 'FIVE FAST SHORT STORIES',
#     'stories': [{'title': 'THE BALLAD OF BLASTER BILL',
#       'author': 'Nelson S. Bond',
#       'intro': "“You'll stand a moment mute; arm raised in full salute, to Blaster Bill....”"},
#      {'title': 'THE DRAGON-QUEEN OF JUPITER',
#       'author': 'Leigh Brackett',
#       'intro': 'More feared than Jupiter’s deadly red beetles was the winged Dragon-Queen.'},
#      {'title': 'GENESIS!',
#       'author': 'R. R. Winterbotham',
#       'intro': 'Renzu dreamed of moulding a mighty race from Venus’ lifeless clay.'},
#      {'title': 'WORLD OF MOCKERY',
#       'author': 'Sam Moskowitz',
#       'intro': 'When John Hall walked on Ganymede, a thousand mocking Beings walked with him.'},
#      {'title': 'SPACE-WOLF',
#       'author': 'Ray Cummings',
#       'intro': 'Titan was a barren world—a weird beast-empire ruled by an Earth-girl queen.'}]},
#    {'title': "P. S.'s DEPARTMENTS",
#     'stories': [{'title': 'FEATURE FLASH',
#       'intro': 'Flashing you the highlights on Raymond Z. Gallon, one of P.S.’s cosmic-minded authors.'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Where the customers bare their kicks and polish their bouquets.'}]}]},
#  {'folder': 'v01n08',
#   'blocks': [{'title': 'A COMPLETE PLANET NOVEL',
#     'stories': [{'title': 'VASSALS OF THE MASTER WORLD',
#       'author': 'Eando Binder',
#       'intro': 'Fettered Earth led the million slave-galaxies in revolt against tyrant Tharkya.'}]},
#    {'title': 'TWO NOVELETS Of OTHER WORLDS',
#     'stories': [{'title': 'THE RAIDERS OF SATURN’S RINGS',
#       'author': 'Raymond Z. Gallun',
#       'intro': 'Only one man could save Titan’s Earth colony from the merciless Callistans.'},
#      {'title': '“SHADRACH”',
#       'author': 'Nelson S. Bond',
#       'intro': 'On frozen Titania, three modern Shadrachs faced the awful test of godship.'}]},
#    {'title': 'FIVE SHORT STORIES',
#     'stories': [{'title': 'THE VICTORY OF KLON',
#       'author': 'Wilbur S. Peacock',
#       'intro': 'Klon, monstrous Lord of Venus, brought his people a deadly triumph.'},
#      {'title': 'THE STAR OF SATAN',
#       'author': 'Henry Hasee',
#       'intro': 'That uncharted star of Satan harbored madness in awful, human form.'},
#      {'title': 'DEAD MAN’S PLANET',
#       'author': 'R. R. Winterbotham',
#       'intro': 'For aeons a dead man kept silent vigil on the barren, ghostly asteroid.'},
#      {'title': 'SOUTH TO PROPONTIS',
#       'author': 'Henry Andrew Ackermann',
#       'intro': 'Between Propontis and the homesick Earth-youth lay the deadly *Avis Gladiator*.'},
#      {'title': 'SPAWN OF THE VENUS SEA',
#       'author': 'Harry Walton',
#       'intro': 'What was this multiple-life monstrosity that rose from Venus’ sea?'}]},
#    {'title': "P. S.'s DEPARTMENTS",
#     'stories': [{'title': 'FEATURE FLASH',
#       'intro': '“Who is Bond; what is he, that all his fans adore him?”'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Where the customers bare their kicks and toss their bouquets.'}]}]},
#  {'folder': 'v01n09',
#   'blocks': [{'title': 'FOUR PLANET NOVELETS',
#     'stories': [{'title': 'THE LORELEI DEATH',
#       'author': 'Nelson S. Bond',
#       'intro': 'Far off the beaten space-lanes the Lorelei of the void plied her deadly trade.'},
#      {'title': 'MAN OF THE STARS',
#       'author': 'Sam Moskowitz',
#       'intro': 'From Earth to Alpha Centatiri, the Universe acclaimed the Master of the Stars.'},
#      {'title': 'ESPIONAGE IN SPACE',
#       'author': 'Alan Connell',
#       'intro': 'The black armadas of Pluto were massed for battle, and Earth could not be warned.'},
#      {'title': 'MONSTER OF THE ASTEROID',
#       'author': 'Ray Cummings',
#       'intro': 'Win or lose, the take was death for those two new slaves of the Monster.'}]},
#    {'title': 'FIVE SHORT STORIES',
#     'stories': [{'title': 'QUEEN OF THE BLUE WORLD',
#       'author': 'Basil Wells',
#       'intro': 'Blue vegetation, red insect-men... Earth was a strange sight to those first Martians.'},
#      {'title': 'A PLANET FOR YOUR THOUGHTS',
#       'author': 'James Norman',
#       'intro': 'In a Universe where thinking was taboo, it was dangerous for Bill Petrie to get ideas.'},
#      {'title': 'THIEF OF MARS',
#       'author': 'Henry Hasse',
#       'intro': 'In limitless space, Earthman and Martian fight the strangest duel the Universe ever saw.'},
#      {'title': 'THE MERCURIAN',
#       'author': 'Frank Belknap Long',
#       'intro': 'Too late Rawley learned of the hideous life that molten, steaming Mercury spawned.'},
#      {'title': 'ZURK',
#       'author': 'Robert O. Lewis',
#       'intro': 'Gentle Marene was next to go when the black space cruiser called for its youth-levy.'}]},
#    {'title': "P. S.'s DEPARTMENTS",
#     'stories': [{'title': 'FEATURE FLASH',
#       'intro': 'Introducing Sam Moskowitz, PLANET’S spotlighted author of the month.'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Kicks and kudoes, bombs and bouquets, from the paying customers.'}]}]},
#  {'folder': 'v01n10',
#   'blocks': [{'title': 'FOUR PLANET NOVELETS',
#     'stories': [{'title': 'BLACK FRIAR OF THE FLAME',
#       'author': 'Isaac Asimov',
#       'intro': 'On despised Earth alone burned the last proud flame of free Humankind.'},
#      {'title': 'GODS OF SPACE',
#       'author': 'Ray Cummings',
#       'intro': 'A strange and beautiful Earthian goddess ruled that tiny star of death.'},
#      {'title': 'THE THING OF VENUS',
#       'author': 'Wilbur S. Peacock',
#       'intro': 'Only disgraced Kenton could save the Earthlings from Venus’ deadly THING.'},
#      {'title': 'CHILD OF THE SUN',
#       'author': 'Leigh Brackett',
#       'intro': 'Out where Vulcan wheeled his hidden orbit, a child of Sol played a cosmic game.'}]},
#    {'title': 'FOUR SHORT STORIES',
#     'stories': [{'title': 'THE STAR-MOUSE',
#       'author': 'Fredric Brown',
#       'intro': 'Crusoe... Gulliver; their adventures are nothing compared to the Saga of Mitkey.'},
#      {'title': 'THE BALLAD OF VENUS NELL',
#       'author': 'Nelson S. Bond',
#       'intro': '“Nell was no saint, any preacher would paint a bad ending for her at a peek.”'},
#      {'title': 'PIED PIPER OF MARS',
#       'author': 'Frederic A, Kummer, Jr.',
#       'intro': 'Elath Taen piped evil, fantastic music for the little men of the Red Planet.'},
#      {'title': 'THE LAST MARTIAN',
#       'author': 'Raymond Van Houten',
#       'intro': 'When the life-giving pumps of Mars stopped, a once-mighty race would die.'}]},
#    {'title': "P. S.'s DEPARTMENTS",
#     'stories': [{'title': 'FEATURE FLASH',
#       'intro': 'Meet Fredric Brown, master of the space-trotting, cosmic-minded Mitkey.'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Kicks and kudoes, bombs and bouquets from the paying customers.'}]}]},
#  {'folder': 'v01n11',
#   'blocks': [{'title': 'THREE PLANET NOVELETS',
#     'stories': [{'title': 'TASK TO LAHRI',
#       'author': 'Ross Rocklynne',
#       'intro': 'The Lahri were dying out, and it was Hallmeyer’s grim task to speed their doom.'},
#      {'title': 'THE STAR-MASTER',
#       'author': 'Ray Cummings',
#       'intro': 'Docile, decadent Venus was easy picking for that twenty-first century Hitler.'},
#      {'title': 'VENUS ENSLAVED',
#       'author': 'Manley Wade Wellman',
#       'intro': 'What chance had those primitive Amazons against the tyrants of the veiled planet?'}]},
#    {'title': 'FIVE SHORT STORIES',
#     'stories': [{'title': 'THE COSMIC DERELICT',
#       'author': 'John Broome',
#       'intro': 'Ever-deeper into the Sargasso of lost space-ships bored the doom-bound *Lucifer*.'},
#      {'title': 'ASTEROID OF THE DAMNED',
#       'author': 'Dirk Wylie',
#       'intro': 'Somewhere on that asteroid of sin was the crime-king of the Universe.'},
#      {'title': 'OUT OF THIS WORLD',
#       'author': 'Henry Hasse',
#       'intro': 'There was no escape but death from the prison planet and its crazed, sadistic keeper.'},
#      {'title': 'CAPTAIN CHAOS',
#       'author': 'Nelson S. Bond',
#       'intro': 'The Callisto-bound *Leo* needed a cook. What it got was a piping-voiced Jonah.'},
#      {'title': 'AS IT WAS',
#       'author': 'Carlton Smith',
#       'intro': 'Back to the awesome birth of Time, Baird sent his aeon-spanning machine.'}]},
#    {'title': "P. S.'s DEPARTMENTS",
#     'stories': [{'title': 'THE RINGER FAMILY (Cartoon)',
#       'author': 'Guy Gifford'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Kicks and kudoes, bombs and bouquets from the paying customers.'}]}]},
#  {'folder': 'v01n12',
#   'blocks': [{'title': 'FOUR PLANET NOVELETS OF OTHER WORLDS',
#     'stories': [{'title': 'WAR-GODS OF THE VOID',
#       'author': 'Henry Kuttner',
#       'intro': 'Ever Northward on Venus, Vanning strode—the mindless slave of the War-Gods’ deadly virus.'},
#      {'title': 'SPACE OASIS',
#       'author': 'Raymond Z. Gallun',
#       'intro': '‘Paradise Asteroid’ it was called—but Norman Haynes meant it to be a spaceway’s Hell.'},
#      {'title': 'VAMPIRE QUEEN',
#       'author': 'Thornton Ayre',
#       'intro': 'Patrolman Curt Stanley trailed the Queen of the Starways into a space-trap of no-escape.'},
#      {'title': 'STELLAR SHOWBOAT',
#       'author': 'Malcolm Jameson',
#       'intro': 'Behind the curtains of the Showboat of Space, Death waited for its cosmic entrance cue.'}]},
#    {'title': 'A WIERD OUTSTANDING PLANET NOVEL',
#     'stories': [{'title': 'CITY OF THE LIVING FLAME',
#       'author': 'Henry Hasse',
#       'intro': 'It was flame from outer space, and it was alive. Unshackled, it would bring doom to all mankind—and Jim Landor had just slain its keeper.'}]},
#    {'title': 'THREE PLANET SHORT STORIES',
#     'stories': [{'title': 'QUEST OF THIG',
#       'author': 'Basil Wells',
#       'intro': 'Man’s emotions are sometimes more deadly than terrible weapons.'},
#      {'title': 'THE THOUGHT-MEN OF MERCURY',
#       'author': 'R. R. Winterbotham',
#       'intro': 'To plan escape, the prisoners had to think—and their captors could read minds.'},
#      {'title': 'PRISON PLANET',
#       'author': 'Bob Tucker',
#       'intro': '‘Rat’ was a criminal—yet he lived by a code that the Ancient Gods might honor.'}]},
#    {'title': "P. S.'s DEPARTMENTS",
#     'stories': [{'title': 'THE FEATURE FLASH',
#       'intro': 'Meet Wilbur S. Peacock, whose Planet yarns you’ve met before.'},
#      {'title': 'THE VIZIGRAPH',
#       'intro': 'Kicks and kudos, bombs and bouquets from the paying customers.'}]}]}]

# %%
# create files

home_folder = "d:\\Epubs\\Planet Stories\\OEBPS"

for magazine in articles[0:11]:
    
    path = os.path.join(home_folder, magazine["folder"])
    
    print(path)
    
    try: {
        os.mkdir(path)
    }
    except FileExistsError: {
        print("folder exists")
    }
    
            # write cover

    html = f'''<?xml version="1.0" encoding="UTF-8"?>
<!DOCTYPE html>
<html xmlns="http://www.w3.org/1999/xhtml" lang="en">
    <head>
        <title>PLANET STORIES</title>
        <link type="text/css" rel="stylesheet" href="css/book.css"/>
    </head>
    <body>
        <div id="cover-image">
            <img src="../images/{magazine["folder"]}.jpg" alt="PLANET STORIES"/>
        </div>
    </body>
</html>
'''
    
    with open(os.path.join(path, "cover.xhtml"), "w", encoding="utf8") as file:
        file.write(html)

    html = f'''<?xml version='1.0' encoding='utf-8'?>
<!DOCTYPE html>
<html xmlns="http://www.w3.org/1999/xhtml" xmlns:epub="http://www.idpf.org/2007/ops" lang="en">
    <head>
        <title>PLANET STORIES</title>
        <link href="css/book.css" type="text/css" rel="stylesheet"/>
    </head>
    <body>
        <div id="toc">
            <h4><img src="../images/old_header.jpg" alt="PLANET STORIES" style="width: 80%;"/></h4>
            <div class="doubleline"></div>
            <div class="president">T. T. SCOTT, President and General Manager</div>
            <div class="editor">MALCOLM REISS, Editor</div>
            <div class="doubleline"></div>
'''
        
    for block in magazine['blocks']:
        html = html + f'''            <h2>{block["title"]}</h2>
            <ol>
'''
        for article in block['stories']:
            filename = article['title'].lower().replace(' ', '_').replace('’', '').replace('?', '').replace('—', '-')
            author = article.get('author', '')
            intro = article.get('intro', '')

            html = html + f'''                <li><a href="{filename}.xhtml">{article["title"].upper()} - {author}</a>
                    <p><i>{intro}</i></p>
                </li>
'''

        html = html + '''            </ol>
'''
        
    html = html + f'''            <div class="doubleline"></div>
            <div class="left-col">VOL {magazine["folder"][1:3]}, No. {magazine["folder"][-2:]}</div>
            <div class="right-col">TODO DATE</div>
            <div class="clear copyright">TODO COPYRIGHT</div>
        </div>
    </body>
</html>
'''
    with open(os.path.join(path, "toc.xhtml"), "w", encoding="utf8") as file:
        file.write(html)

    for block in magazine['blocks']:
        for article in block['stories']:
            filename = article['title'].lower().replace(' ', '_').replace('’', '').replace('?', '').replace('—', '-')
            author = article.get('author', '')

            html = f'''<?xml version='1.0' encoding='utf-8'?>
<!DOCTYPE html>
<html xmlns="http://www.w3.org/1999/xhtml" xmlns:epub="http://www.idpf.org/2007/ops" lang="en">
    <head>
        <title>PLANET STORIES</title>
        <link href="css/book.css" type="text/css" rel="stylesheet"/>
    </head>
    <body>
        <div id="story">
            <h1>{article["title"]}</h1>
            <h2><i>By {author}</i></h2>
            <h3></h3>

        </div>
    </body>
</html>
'''
            with open(os.path.join(path, f"{filename}.xhtml"), "w", encoding="utf8") as file:
                file.write(html)
# Out:
# d:\Epubs\Planet Stories\OEBPS\v01n02
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n03
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n04
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n05
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n06
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n07
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n08
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n09
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n10
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n11
# folder exists
# d:\Epubs\Planet Stories\OEBPS\v01n12
# folder exists

# %%
# write toc extension

for volume in articles:
    for contents in volume["volume"]:
        html = f'''                <li><a href="{volume["folder"]}/{contents["folder"]}/cover.xhtml">Volume {contents["volume"]} Number {contents["number"]}</a>
                    <ol>
                        <li><a href="{volume["folder"]}/{contents["folder"]}/toc.xhtml">Contents</a></li>
'''

        for article in contents['content']:
            html = html + f'''                        <li><a href="{volume["folder"]}/{contents["folder"]}/{article["file"]}.xhtml"><span class="smallcaps">{article["title"]}</span> - {article["author"].upper()}</a></li>
'''
        html = html + f'''                    </ol>
                </li>
'''

        print(html)

# %%
# ncx extension

# %%
# opf extension manifest

for magazine in articles[0:11]:
    manifest = f'        <item id="{magazine["folder"]}-cover" href="{magazine["folder"]}/cover.xhtml" media-type="application/xhtml+xml"/>'
    print(manifest)
    manifest = f'        <item id="{magazine["folder"]}-toc" href="{magazine["folder"]}/toc.xhtml" media-type="application/xhtml+xml"/>'
    print(manifest)

    for block in magazine["blocks"]:

        for article in block['stories']:

            filename = article['title'].lower().replace(' ', '_').replace('’', '').replace('?', '').replace('—', '-')

            manifest = f'        <item id="{filename}" href="{magazine["folder"]}/{filename}.xhtml" media-type="application/xhtml+xml"/>'
            print(manifest)
# Out:
#         <item id="v01n02-cover" href="v01n02/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n02-toc" href="v01n02/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="goddess_of_the_moon" href="v01n02/goddess_of_the_moon.xhtml" media-type="application/xhtml+xml"/>
#         <item id="dictator_of_time" href="v01n02/dictator_of_time.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_girl_from_infinite_smallness" href="v01n02/the_girl_from_infinite_smallness.xhtml" media-type="application/xhtml+xml"/>
#         <item id="martian_terror" href="v01n02/martian_terror.xhtml" media-type="application/xhtml+xml"/>
#         <item id="revolt_on_the_earth-star" href="v01n02/revolt_on_the_earth-star.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_tantalus_death" href="v01n02/the_tantalus_death.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_space_flame" href="v01n02/the_space_flame.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_man_who_killed_the_earth" href="v01n02/the_man_who_killed_the_earth.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_feature_flash" href="v01n02/the_feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n02/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n03-cover" href="v01n03/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n03-toc" href="v01n03/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="space-liner_x-87" href="v01n03/space-liner_x-87.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_forbidden_dream" href="v01n03/the_forbidden_dream.xhtml" media-type="application/xhtml+xml"/>
#         <item id="exiles_of_the_three_red_moons" href="v01n03/exiles_of_the_three_red_moons.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_cosmic_juggernaut" href="v01n03/the_cosmic_juggernaut.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_dark_swordsmen_of_saturn" href="v01n03/the_dark_swordsmen_of_saturn.xhtml" media-type="application/xhtml+xml"/>
#         <item id="sphere_of_the_never-dead" href="v01n03/sphere_of_the_never-dead.xhtml" media-type="application/xhtml+xml"/>
#         <item id="star_pirate" href="v01n03/star_pirate.xhtml" media-type="application/xhtml+xml"/>
#         <item id="asteroid_h277-plus" href="v01n03/asteroid_h277-plus.xhtml" media-type="application/xhtml+xml"/>
#         <item id="life_on_other_planets" href="v01n03/life_on_other_planets.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_feature_flash" href="v01n03/the_feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n03/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n04-cover" href="v01n04/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n04-toc" href="v01n04/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_ultimate_salient" href="v01n04/the_ultimate_salient.xhtml" media-type="application/xhtml+xml"/>
#         <item id="revolt_in_the_ice_kingdom" href="v01n04/revolt_in_the_ice_kingdom.xhtml" media-type="application/xhtml+xml"/>
#         <item id="buccaneer_of_the_star_seas" href="v01n04/buccaneer_of_the_star_seas.xhtml" media-type="application/xhtml+xml"/>
#         <item id="domain_of_zero" href="v01n04/domain_of_zero.xhtml" media-type="application/xhtml+xml"/>
#         <item id="quest_on_io" href="v01n04/quest_on_io.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_planet_that_time_forgot" href="v01n04/the_planet_that_time_forgot.xhtml" media-type="application/xhtml+xml"/>
#         <item id="hermit_of_saturns_ring" href="v01n04/hermit_of_saturns_ring.xhtml" media-type="application/xhtml+xml"/>
#         <item id="venus_has_green_eyes" href="v01n04/venus_has_green_eyes.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_feature_flash" href="v01n04/the_feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n04/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n05-cover" href="v01n05/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n05-toc" href="v01n05/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="one_thousand_miles_below" href="v01n05/one_thousand_miles_below.xhtml" media-type="application/xhtml+xml"/>
#         <item id="phantom_of_the_seven_stars" href="v01n05/phantom_of_the_seven_stars.xhtml" media-type="application/xhtml+xml"/>
#         <item id="twilight_of_the_tenth_world" href="v01n05/twilight_of_the_tenth_world.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_castaway" href="v01n05/the_castaway.xhtml" media-type="application/xhtml+xml"/>
#         <item id="atom_of_death" href="v01n05/atom_of_death.xhtml" media-type="application/xhtml+xml"/>
#         <item id="beyond_light" href="v01n05/beyond_light.xhtml" media-type="application/xhtml+xml"/>
#         <item id="exit_from_asteroid_60" href="v01n05/exit_from_asteroid_60.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_stellar_legion" href="v01n05/the_stellar_legion.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_feature_flash" href="v01n05/the_feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n05/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n06-cover" href="v01n06/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n06-toc" href="v01n06/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_war-nymphs_of_venus" href="v01n06/the_war-nymphs_of_venus.xhtml" media-type="application/xhtml+xml"/>
#         <item id="vampire_of_the_void" href="v01n06/vampire_of_the_void.xhtml" media-type="application/xhtml+xml"/>
#         <item id="exiles_of_the_desert_star" href="v01n06/exiles_of_the_desert_star.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_monster_that_threatened_the_universe" href="v01n06/the_monster_that_threatened_the_universe.xhtml" media-type="application/xhtml+xml"/>
#         <item id="treasure_of_triton" href="v01n06/treasure_of_triton.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_cosmic_derelict" href="v01n06/the_cosmic_derelict.xhtml" media-type="application/xhtml+xml"/>
#         <item id="4½_b,_eros" href="v01n06/4½_b,_eros.xhtml" media-type="application/xhtml+xml"/>
#         <item id="satellite_of_fear" href="v01n06/satellite_of_fear.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n06/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n07-cover" href="v01n07/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n07-toc" href="v01n07/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="invaders_of_the_forbidden_moon" href="v01n07/invaders_of_the_forbidden_moon.xhtml" media-type="application/xhtml+xml"/>
#         <item id="sargasso_of_the_stars" href="v01n07/sargasso_of_the_stars.xhtml" media-type="application/xhtml+xml"/>
#         <item id="mutiny_aboard_the_“terra”" href="v01n07/mutiny_aboard_the_“terra”.xhtml" media-type="application/xhtml+xml"/>
#         <item id="proktols_of_neptune" href="v01n07/proktols_of_neptune.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_ballad_of_blaster_bill" href="v01n07/the_ballad_of_blaster_bill.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_dragon-queen_of_jupiter" href="v01n07/the_dragon-queen_of_jupiter.xhtml" media-type="application/xhtml+xml"/>
#         <item id="genesis!" href="v01n07/genesis!.xhtml" media-type="application/xhtml+xml"/>
#         <item id="world_of_mockery" href="v01n07/world_of_mockery.xhtml" media-type="application/xhtml+xml"/>
#         <item id="space-wolf" href="v01n07/space-wolf.xhtml" media-type="application/xhtml+xml"/>
#         <item id="feature_flash" href="v01n07/feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n07/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n08-cover" href="v01n08/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n08-toc" href="v01n08/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="vassals_of_the_master_world" href="v01n08/vassals_of_the_master_world.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_raiders_of_saturns_rings" href="v01n08/the_raiders_of_saturns_rings.xhtml" media-type="application/xhtml+xml"/>
#         <item id="“shadrach”" href="v01n08/“shadrach”.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_victory_of_klon" href="v01n08/the_victory_of_klon.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_star_of_satan" href="v01n08/the_star_of_satan.xhtml" media-type="application/xhtml+xml"/>
#         <item id="dead_mans_planet" href="v01n08/dead_mans_planet.xhtml" media-type="application/xhtml+xml"/>
#         <item id="south_to_propontis" href="v01n08/south_to_propontis.xhtml" media-type="application/xhtml+xml"/>
#         <item id="spawn_of_the_venus_sea" href="v01n08/spawn_of_the_venus_sea.xhtml" media-type="application/xhtml+xml"/>
#         <item id="feature_flash" href="v01n08/feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n08/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n09-cover" href="v01n09/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n09-toc" href="v01n09/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_lorelei_death" href="v01n09/the_lorelei_death.xhtml" media-type="application/xhtml+xml"/>
#         <item id="man_of_the_stars" href="v01n09/man_of_the_stars.xhtml" media-type="application/xhtml+xml"/>
#         <item id="espionage_in_space" href="v01n09/espionage_in_space.xhtml" media-type="application/xhtml+xml"/>
#         <item id="monster_of_the_asteroid" href="v01n09/monster_of_the_asteroid.xhtml" media-type="application/xhtml+xml"/>
#         <item id="queen_of_the_blue_world" href="v01n09/queen_of_the_blue_world.xhtml" media-type="application/xhtml+xml"/>
#         <item id="a_planet_for_your_thoughts" href="v01n09/a_planet_for_your_thoughts.xhtml" media-type="application/xhtml+xml"/>
#         <item id="thief_of_mars" href="v01n09/thief_of_mars.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_mercurian" href="v01n09/the_mercurian.xhtml" media-type="application/xhtml+xml"/>
#         <item id="zurk" href="v01n09/zurk.xhtml" media-type="application/xhtml+xml"/>
#         <item id="feature_flash" href="v01n09/feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n09/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n10-cover" href="v01n10/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n10-toc" href="v01n10/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="black_friar_of_the_flame" href="v01n10/black_friar_of_the_flame.xhtml" media-type="application/xhtml+xml"/>
#         <item id="gods_of_space" href="v01n10/gods_of_space.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_thing_of_venus" href="v01n10/the_thing_of_venus.xhtml" media-type="application/xhtml+xml"/>
#         <item id="child_of_the_sun" href="v01n10/child_of_the_sun.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_star-mouse" href="v01n10/the_star-mouse.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_ballad_of_venus_nell" href="v01n10/the_ballad_of_venus_nell.xhtml" media-type="application/xhtml+xml"/>
#         <item id="pied_piper_of_mars" href="v01n10/pied_piper_of_mars.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_last_martian" href="v01n10/the_last_martian.xhtml" media-type="application/xhtml+xml"/>
#         <item id="feature_flash" href="v01n10/feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n10/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n11-cover" href="v01n11/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n11-toc" href="v01n11/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="task_to_lahri" href="v01n11/task_to_lahri.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_star-master" href="v01n11/the_star-master.xhtml" media-type="application/xhtml+xml"/>
#         <item id="venus_enslaved" href="v01n11/venus_enslaved.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_cosmic_derelict" href="v01n11/the_cosmic_derelict.xhtml" media-type="application/xhtml+xml"/>
#         <item id="asteroid_of_the_damned" href="v01n11/asteroid_of_the_damned.xhtml" media-type="application/xhtml+xml"/>
#         <item id="out_of_this_world" href="v01n11/out_of_this_world.xhtml" media-type="application/xhtml+xml"/>
#         <item id="captain_chaos" href="v01n11/captain_chaos.xhtml" media-type="application/xhtml+xml"/>
#         <item id="as_it_was" href="v01n11/as_it_was.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_ringer_family_(cartoon)" href="v01n11/the_ringer_family_(cartoon).xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n11/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n12-cover" href="v01n12/cover.xhtml" media-type="application/xhtml+xml"/>
#         <item id="v01n12-toc" href="v01n12/toc.xhtml" media-type="application/xhtml+xml"/>
#         <item id="war-gods_of_the_void" href="v01n12/war-gods_of_the_void.xhtml" media-type="application/xhtml+xml"/>
#         <item id="space_oasis" href="v01n12/space_oasis.xhtml" media-type="application/xhtml+xml"/>
#         <item id="vampire_queen" href="v01n12/vampire_queen.xhtml" media-type="application/xhtml+xml"/>
#         <item id="stellar_showboat" href="v01n12/stellar_showboat.xhtml" media-type="application/xhtml+xml"/>
#         <item id="city_of_the_living_flame" href="v01n12/city_of_the_living_flame.xhtml" media-type="application/xhtml+xml"/>
#         <item id="quest_of_thig" href="v01n12/quest_of_thig.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_thought-men_of_mercury" href="v01n12/the_thought-men_of_mercury.xhtml" media-type="application/xhtml+xml"/>
#         <item id="prison_planet" href="v01n12/prison_planet.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_feature_flash" href="v01n12/the_feature_flash.xhtml" media-type="application/xhtml+xml"/>
#         <item id="the_vizigraph" href="v01n12/the_vizigraph.xhtml" media-type="application/xhtml+xml"/>

# %%
# opf extension spine

for magazine in articles[0:11]:
    spine = f'        <itemref idref="{magazine["folder"]}-cover"/>'
    print(spine)
    spine = f'        <itemref idref="{magazine["folder"]}-toc"/>'
    print(spine)

    for block in magazine["blocks"]:
        for article in block['stories']:

            filename = article['title'].lower().replace(' ', '_').replace('’', '').replace('?', '').replace('—', '-')

            spine = f'        <itemref idref="{filename}"/>'
            print(spine)
# Out:
#         <itemref idref="v01n02-cover"/>
#         <itemref idref="v01n02-toc"/>
#         <itemref idref="goddess_of_the_moon"/>
#         <itemref idref="dictator_of_time"/>
#         <itemref idref="the_girl_from_infinite_smallness"/>
#         <itemref idref="martian_terror"/>
#         <itemref idref="revolt_on_the_earth-star"/>
#         <itemref idref="the_tantalus_death"/>
#         <itemref idref="the_space_flame"/>
#         <itemref idref="the_man_who_killed_the_earth"/>
#         <itemref idref="the_feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n03-cover"/>
#         <itemref idref="v01n03-toc"/>
#         <itemref idref="space-liner_x-87"/>
#         <itemref idref="the_forbidden_dream"/>
#         <itemref idref="exiles_of_the_three_red_moons"/>
#         <itemref idref="the_cosmic_juggernaut"/>
#         <itemref idref="the_dark_swordsmen_of_saturn"/>
#         <itemref idref="sphere_of_the_never-dead"/>
#         <itemref idref="star_pirate"/>
#         <itemref idref="asteroid_h277-plus"/>
#         <itemref idref="life_on_other_planets"/>
#         <itemref idref="the_feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n04-cover"/>
#         <itemref idref="v01n04-toc"/>
#         <itemref idref="the_ultimate_salient"/>
#         <itemref idref="revolt_in_the_ice_kingdom"/>
#         <itemref idref="buccaneer_of_the_star_seas"/>
#         <itemref idref="domain_of_zero"/>
#         <itemref idref="quest_on_io"/>
#         <itemref idref="the_planet_that_time_forgot"/>
#         <itemref idref="hermit_of_saturns_ring"/>
#         <itemref idref="venus_has_green_eyes"/>
#         <itemref idref="the_feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n05-cover"/>
#         <itemref idref="v01n05-toc"/>
#         <itemref idref="one_thousand_miles_below"/>
#         <itemref idref="phantom_of_the_seven_stars"/>
#         <itemref idref="twilight_of_the_tenth_world"/>
#         <itemref idref="the_castaway"/>
#         <itemref idref="atom_of_death"/>
#         <itemref idref="beyond_light"/>
#         <itemref idref="exit_from_asteroid_60"/>
#         <itemref idref="the_stellar_legion"/>
#         <itemref idref="the_feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n06-cover"/>
#         <itemref idref="v01n06-toc"/>
#         <itemref idref="the_war-nymphs_of_venus"/>
#         <itemref idref="vampire_of_the_void"/>
#         <itemref idref="exiles_of_the_desert_star"/>
#         <itemref idref="the_monster_that_threatened_the_universe"/>
#         <itemref idref="treasure_of_triton"/>
#         <itemref idref="the_cosmic_derelict"/>
#         <itemref idref="4½_b,_eros"/>
#         <itemref idref="satellite_of_fear"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n07-cover"/>
#         <itemref idref="v01n07-toc"/>
#         <itemref idref="invaders_of_the_forbidden_moon"/>
#         <itemref idref="sargasso_of_the_stars"/>
#         <itemref idref="mutiny_aboard_the_“terra”"/>
#         <itemref idref="proktols_of_neptune"/>
#         <itemref idref="the_ballad_of_blaster_bill"/>
#         <itemref idref="the_dragon-queen_of_jupiter"/>
#         <itemref idref="genesis!"/>
#         <itemref idref="world_of_mockery"/>
#         <itemref idref="space-wolf"/>
#         <itemref idref="feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n08-cover"/>
#         <itemref idref="v01n08-toc"/>
#         <itemref idref="vassals_of_the_master_world"/>
#         <itemref idref="the_raiders_of_saturns_rings"/>
#         <itemref idref="“shadrach”"/>
#         <itemref idref="the_victory_of_klon"/>
#         <itemref idref="the_star_of_satan"/>
#         <itemref idref="dead_mans_planet"/>
#         <itemref idref="south_to_propontis"/>
#         <itemref idref="spawn_of_the_venus_sea"/>
#         <itemref idref="feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n09-cover"/>
#         <itemref idref="v01n09-toc"/>
#         <itemref idref="the_lorelei_death"/>
#         <itemref idref="man_of_the_stars"/>
#         <itemref idref="espionage_in_space"/>
#         <itemref idref="monster_of_the_asteroid"/>
#         <itemref idref="queen_of_the_blue_world"/>
#         <itemref idref="a_planet_for_your_thoughts"/>
#         <itemref idref="thief_of_mars"/>
#         <itemref idref="the_mercurian"/>
#         <itemref idref="zurk"/>
#         <itemref idref="feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n10-cover"/>
#         <itemref idref="v01n10-toc"/>
#         <itemref idref="black_friar_of_the_flame"/>
#         <itemref idref="gods_of_space"/>
#         <itemref idref="the_thing_of_venus"/>
#         <itemref idref="child_of_the_sun"/>
#         <itemref idref="the_star-mouse"/>
#         <itemref idref="the_ballad_of_venus_nell"/>
#         <itemref idref="pied_piper_of_mars"/>
#         <itemref idref="the_last_martian"/>
#         <itemref idref="feature_flash"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n11-cover"/>
#         <itemref idref="v01n11-toc"/>
#         <itemref idref="task_to_lahri"/>
#         <itemref idref="the_star-master"/>
#         <itemref idref="venus_enslaved"/>
#         <itemref idref="the_cosmic_derelict"/>
#         <itemref idref="asteroid_of_the_damned"/>
#         <itemref idref="out_of_this_world"/>
#         <itemref idref="captain_chaos"/>
#         <itemref idref="as_it_was"/>
#         <itemref idref="the_ringer_family_(cartoon)"/>
#         <itemref idref="the_vizigraph"/>
#         <itemref idref="v01n12-cover"/>
#         <itemref idref="v01n12-toc"/>
#         <itemref idref="war-gods_of_the_void"/>
#         <itemref idref="space_oasis"/>
#         <itemref idref="vampire_queen"/>
#         <itemref idref="stellar_showboat"/>
#         <itemref idref="city_of_the_living_flame"/>
#         <itemref idref="quest_of_thig"/>
#         <itemref idref="the_thought-men_of_mercury"/>
#         <itemref idref="prison_planet"/>
#         <itemref idref="the_feature_flash"/>
#         <itemref idref="the_vizigraph"/>
